# %% [markdown]
# Linear Regression - Project Exercise Congratulations! You just got some contract work with an Ecommerce company based in New York City that sells clothing online but they also have in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want.
#
# The company is trying to decide whether to focus their efforts on their mobile app experience or their website. They've hired you on contract to help them figure it out! Let's get started!
#
# Just follow the steps below to analyze the customer data (it's fake, don't worry I didn't give you real credit card numbers or emails).

# %%
import pandas as pd

# %%
data = pd.read_csv("E:\DATA-SCIENCE\Lecture_files\ML\Ecommerce Customers.csv")

# %%
data
# Out:
#                              Email
# 0        mstephenson@fernandez.com  \
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet  \
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website
# count           500.000000   500.000000       500.000000  \
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
data.shape
# Out:
# (500, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Now we only use the numerical data from our dataset and drop another data from csv file

# %% [markdown]
# Use seaborn to create a jointplot to compare the Time on Website and Yearly Amount Spent columns. Does the correlation make sense?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.jointplot(x="Time on Website", y= "Yearly Amount Spent",data=data);

# %%
plt.scatter(x="Time on Website", y= "Yearly Amount Spent",data=data);

# %%
sns.jointplot(x="Time on App", y= "Yearly Amount Spent",data=data);

# %% [markdown]
# Comparing time on app and length of membership

# %%
sns.jointplot(x="Time on App", y= "Length of Membership",data=data);

# %%
sns.jointplot(x="Time on App", y= "Length of Membership",kind="kde",data=data);

# %%
plt.hist(data['Time on Website']);

# %%
plt.hist(data['Yearly Amount Spent']);

# %%
plt.boxplot(data['Yearly Amount Spent']); #show the median value of selected data

# %%
sns.pairplot(data,hue="Yearly Amount Spent");

# %%
sns.pairplot(data=data);

# %% [markdown]
# # Based off this plot what looks to be the most correlated feature with Yearly Amount Spent?

# %% [markdown]
# Create a linear model plot (using seaborn's lmplot) of Yearly Amount Spent vs. Length of Membership.

# %%
sns.set(color_codes=True)
sns.lmplot(x="Length of Membership",y="Yearly Amount Spent",data=data);

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
sns.set(color_codes=True)
sns.lmplot(x="Time on App",y="Yearly Amount Spent",data=data);

# %%
cust_data = data.iloc[:,3:]

# %%
cust_data
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621  \
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# ...

# %%
cust_data.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website
# Avg. Session Length              1.000000    -0.027826        -0.034987  \
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %% [markdown]
# # Training and Testing Data

# %% [markdown]
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets. Set a variable X equal to the numerical features of the customers and a variable y equal to the "Yearly Amount Spent" column.

# %%
X = cust_data.iloc[:,:4]

# %%
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
y = cust_data['Yearly Amount Spent']

# %%
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64

# %% [markdown]
# Split the Data for model training 70% and testing 30%

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
print(f"train data shape: {X_train.shape} and {Y_train.shape}")
print(f"test data shape: {X_test.shape} and {Y_test.shape}")
# Out:
# train data shape: (350, 4) and (350,)
# test data shape: (150, 4) and (150,)

# %% [markdown]
# # Train the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
model_1 = lm.fit(X_train,Y_train)

# %%
print("slop:",model_1.coef_)
# Out:
# slop: [25.98154972 38.59015875  0.19040528 61.27909654]

# %%
print("intercept",model_1.intercept_)
# Out:
# intercept -1047.9327822502391

# %% [markdown]
# # Prediction of trained data

# %%
prediction_1 = model_1.predict(X_test)

# %%
prediction_1
# Out:
# array([456.44186104, 402.72005312, 409.2531539 , 591.4310343 ,
#        590.01437275, 548.82396607, 577.59737969, 715.44428115,
#        473.7893446 , 545.9211364 , 337.8580314 , 500.38506697,
#        552.93478041, 409.6038964 , 765.52590754, 545.83973731,
#        693.25969124, 507.32416226, 573.10533175, 573.2076631 ,
#        397.44989709, 555.0985107 , 458.19868141, 482.66899911,
#        559.2655959 , 413.00946082, 532.25727408, 377.65464817,
#        535.0209653 , 447.80070905, 595.54339577, 667.14347072,
#        511.96042791, 573.30433971, 505.02260887, 565.30254655,
#        460.38785393, 449.74727868, 422.87193429, 456.55615271,
#        598.10493696, 449.64517443, 615.34948995, 511.88078685,
#        504.37568058, 515.95249276, 568.64597718, 551.61444684,
#        356.5552241 , 464.9759817 , 481.66007708, 534.2220025 ,
#        256.28674001, 505.30810714, 520.01844434, 315.0298707 ,
#        501.98080155, 387.03842642, 472.97419543, 432.8704675 ,
# ...

# %% [markdown]
# # Create a scatterplot of the real test values versus the predicted values.

# %%
plt.scatter(x = Y_test, y = prediction_1, color="Red");
plt.ylabel("predicted value")
plt.xlabel("Real value")
# Out:
# Text(0.5, 0, 'Real value')

# %%
print("Accuracy:{}%".format(model_1.score(X_test,Y_test)*100))
# Out:
# Accuracy:98.90046246741234%

# %%
sns.scatterplot(x=Y_test,y=prediction_1)
# Out:
# <Axes: xlabel='Yearly Amount Spent'>

# %% [markdown]
# # Evaluation of model

# %% [markdown]
# Let's evaluate our model performance by calculating the residual sum of squares and the explained variance score (R^2).
#
# Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error.

# %%
import sklearn.metrics as metrics
import numpy as np

# %%
print(f"MAE:{metrics.mean_absolute_error(Y_test,prediction_1)}")
print(f"MSE:{metrics.mean_squared_error(Y_test,prediction_1)}")
print(f"RMSE:{np.sqrt(metrics.mean_squared_error(Y_test,prediction_1))}")
# Out:
# MAE:7.228148653430826
# MSE:79.81305165097427
# RMSE:8.933815066978624

# %% [markdown]
# Plot a histogram of the residuals and make sure it looks normally distributed
# The difference between what was expected and what was predicted is called the residual error. It is calculated as: residual error = expected - predicted.

# %%
sns.histplot((Y_test-prediction_1));

# %%
pd.DataFrame(model_1.coef_,X.columns,columns=['Coefficient'])
# Out:
#                       Coefficient
# Avg. Session Length     25.981550
# Time on App             38.590159
# Time on Website          0.190405
# Length of Membership    61.279097

# %%
model_1.coef_?

# %%
model_1.intercept_ #when all independant variable are zero than this intercept is -1047.93 but its's doesn't related with our data as ourdata never be zero
# Out:
# -1047.9327822502391

# %% [markdown]
# # Conclusion

# %% [markdown]
# **The company should focus on the mobile app
# 1)because of time on app Coeffecient is 38.59 so everytime if one unit increase in time spent on app the predicted yearly amount spent increase by 38.59. its cleary indicates that users who spend more time on app spend more annually.
# 2)for every unit the increase of the membership the spend increase by 61 so the longer member spend higher annually.

# %% [markdown]
# # just for understand the multiple linear model

# %%
X1 = cust_data.iloc[:,:4]
Y1 = cust_data.iloc[:,4:]

# %%
Y1
# Out:
#      Yearly Amount Spent
# 0             587.951054
# 1             392.204933
# 2             487.547505
# 3             581.852344
# 4             599.406092
# ..                   ...
# 495           573.847438
# 496           529.049004
# 497           551.620145
# 498           456.469510
# 499           497.778642
#
# [500 rows x 1 columns]

# %%
X1
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
#model coefficient and intercept
25.98154972 *34.497268  + 38.59015875*12.655651 +  0.19040528* 39.577668    +61.27909654 *4.082621 -1047.932782250239
# Out:
# 594.4584060230407

# %%
25.98154972*31.926272+  38.59015875*11.109461+ 0.19040528*37.268959 + 61.27909654*2.664034 - 1047.932782250239
# Out:
# 380.6229079544844
